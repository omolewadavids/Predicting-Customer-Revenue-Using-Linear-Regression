# %% [markdown]
# # Prediction Customer Revenue Using Linear Regression

# %% [markdown]
# ### Import pandas and read the dataset

# %%
import pandas as pd

# %%
df = pd.read_csv('retail_transaction.csv')

# %%
df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     546729     22775  PURPLE DRAWERKNOB ACRYLIC EDWARDIAN        12
# 1     559898     21868                 POTTING SHED TEA MUG         6
# 2     548648     71459       HANGING JAM JAR T-LIGHT HOLDER        24
# 3     540543     22173   METAL 4 HOOK HANGER FRENCH CHATEAU         4
# 4     561390     20726                   LUNCH BAG WOODLAND        10
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2011-03-16 11:36:00       1.25     18231.0  United Kingdom
# 1  2011-07-13 12:18:00       1.25     16225.0  United Kingdom
# 2  2011-04-01 13:20:00       0.85     12949.0  United Kingdom
# 3  2011-01-09 15:23:00       2.95     14395.0  United Kingdom
# 4  2011-07-27 09:52:00       1.65     17068.0  United Kingdom

# %% [markdown]
# ### Data Wrangling

# %%
# Convert the InvoiceDate column to date format
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         546729     22775  PURPLE DRAWERKNOB ACRYLIC EDWARDIAN        12
# 1         559898     21868                 POTTING SHED TEA MUG         6
# 2         548648     71459       HANGING JAM JAR T-LIGHT HOLDER        24
# 3         540543     22173   METAL 4 HOOK HANGER FRENCH CHATEAU         4
# 4         561390     20726                   LUNCH BAG WOODLAND        10
# ...          ...       ...                                  ...       ...
# 43296     541293     21080  SET/20 RED RETROSPOT PAPER NAPKINS          2
# 43297     581133     85212      MINI PAINTED GARDEN DECORATION         24
# 43298     577696    85099C       JUMBO  BAG BAROQUE BLACK WHITE         2
# 43299     564198     21787                RAIN PONCHO RETROSPOT         3
# 43300     567306     22614          PACK OF 12 SPACEBOY TISSUES        48
#
#               InvoiceDate  UnitPrice  CustomerID         Country
# 0     2011-03-16 11:36:00       1.25     18231.0  United Kingdom
# 1     2011-07-13 12:18:00       1.25     16225.0  United Kingdom
# 2     2011-04-01 13:20:00       0.85     12949.0  United Kingdom
# 3     2011-01-09 15:23:00       2.95     14395.0  United Kingdom
# 4     2011-07-27 09:52:00       1.65     17068.0  United Kingdom
# ...                   ...        ...         ...             ...
# 43296 2011-01-17 13:39:00       0.85     15311.0  United Kingdom
# 43297 2011-12-07 12:55:00       0.29     14904.0  United Kingdom
# 43298 2011-11-21 11:57:00       2.08     16406.0  United Kingdom
# 43299 2011-08-23 17:18:00       0.85     14418.0  United Kingdom
# 43300 2011-09-19 13:32:00       0.29     12752.0          Norway
#
# [43301 rows x 8 columns]

# %% [markdown]
# #### Calculate revenue for each row

# %%
df['revenue'] = df['UnitPrice'] * df['Quantity']

# %%
operations = {'revenue' : 'sum', 'InvoiceDate' : 'first', 'CustomerID' : 'first'}

df = df.groupby('InvoiceNo').agg(operations)

# %%
df.head()
# Out:
#            revenue         InvoiceDate  CustomerID
# InvoiceNo
# 536365       20.34 2010-12-01 08:26:00     17850.0
# 536367       54.08 2010-12-01 08:34:00     13047.0
# 536373       61.14 2010-12-01 09:02:00     17850.0
# 536378       88.20 2010-12-01 09:37:00     14688.0
# 536381       44.20 2010-12-01 09:41:00     15311.0

# %%
# The prediction will be based on year, create a column for year
df['year'] = df['InvoiceDate'].apply(lambda x: x.year)

# %%
df.head()
# Out:
#            revenue         InvoiceDate  CustomerID  year
# InvoiceNo
# 536365       20.34 2010-12-01 08:26:00     17850.0  2010
# 536367       54.08 2010-12-01 08:34:00     13047.0  2010
# 536373       61.14 2010-12-01 09:02:00     17850.0  2010
# 536378       88.20 2010-12-01 09:37:00     14688.0  2010
# 536381       44.20 2010-12-01 09:41:00     15311.0  2010

# %%
# Since date of transaction is also a source of feature
df['days_since'] = (pd.datetime(year=2010, month=12, day=31) - df['InvoiceDate']).apply(lambda x : x.days)

# %%
# Calculate the minimum and maximum number of days and group by unique values
operations = {'revenue':'sum', 'days_since':['max', 'min', 'nunique'],}

x = df[df['year'] == 2010].groupby('CustomerID').agg(operations)

# %%
x.head()
# Out:
#            revenue days_since
#                sum        max min nunique
# CustomerID
# 12347.0      52.50         23  23       1
# 12348.0     129.60         14  14       1
# 12370.0     271.46         16  13       2
# 12377.0     129.24         10  10       1
# 12383.0      22.92          8   8       1

# %%
# Column name rename
x.columns = [' '.join(col).strip() for col in x.columns.values]

# %%
x.head()
# Out:
#             revenue sum  days_since max  days_since min  days_since nunique
# CustomerID
# 12347.0           52.50              23              23                   1
# 12348.0          129.60              14              14                   1
# 12370.0          271.46              16              13                   2
# 12377.0          129.24              10              10                   1
# 12383.0           22.92               8               8                   1

# %%
# Calculate average spend per order
x['avg_order_cost'] = x['revenue sum']/x['days_since nunique']

# %%
y = df[df['year'] == 2011].groupby('CustomerID')['revenue'].sum()

# %%
# Merge predictors and outcomes into a single dataframe
wrangled_df = pd.concat([x, y], axis=1)
wrangled_df.columns = ['2010 revenue',
                      'days_since_first_purchase',
                      'days_since_last_purchase',
                      'number_of_purchases',
                      'avg_order_cost',
                      '2011 revenue']

# %%
wrangled_df.head()
# Out:
#             2010 revenue  days_since_first_purchase  days_since_last_purchase  \
# CustomerID
# 12347.0             52.5                       23.0                      23.0
# 12348.0            129.6                       14.0                      14.0
# 12349.0              NaN                        NaN                       NaN
# 12350.0              NaN                        NaN                       NaN
# 12352.0              NaN                        NaN                       NaN
#
#             number_of_purchases  avg_order_cost  2011 revenue
# CustomerID
# 12347.0                     1.0            52.5        517.81
# 12348.0                     1.0           129.6           NaN
# 12349.0                     NaN             NaN         89.13
# 12350.0                     NaN             NaN         62.70
# 12352.0                     NaN             NaN        133.30

# %%
# There are so many values in the dataframe caused by some customers that were either actived in 2010 
# but not in 2011 or active in 2011 but not in 2010
wrangled_df = wrangled_df[~wrangled_df['2010 revenue'].isnull()]
wrangled_df = wrangled_df[~wrangled_df['2011 revenue'].isnull()]

# %%
wrangled_df
# Out:
#             2010 revenue  days_since_first_purchase  days_since_last_purchase  \
# CustomerID
# 12347.0            52.50                       23.0                      23.0
# 12370.0           271.46                       16.0                      13.0
# 12377.0           129.24                       10.0                      10.0
# 12383.0            22.92                        8.0                       8.0
# 12395.0            89.30                       27.0                      13.0
# ...                  ...                        ...                       ...
# 18223.0            83.40                       14.0                      14.0
# 18239.0            75.20                       28.0                      28.0
# 18245.0            23.50                       11.0                      11.0
# 18259.0            50.40                       22.0                      22.0
# 18260.0            15.90                       14.0                      14.0
#
#             number_of_purchases  avg_order_cost  2011 revenue
# CustomerID
# 12347.0                     1.0           52.50        517.81
# 12370.0                     2.0          135.73        203.50
# 12377.0                     1.0          129.24         91.56
# 12383.0                     1.0           22.92        110.60
# 12395.0                     2.0           44.65        265.29
# ...                         ...             ...           ...
# 18223.0                     1.0           83.40        707.21
# 18239.0                     1.0           75.20         30.00
# 18245.0                     1.0           23.50        220.62
# 18259.0                     1.0           50.40        131.60
# 18260.0                     1.0           15.90        289.46
#
# [576 rows x 6 columns]

# %%
# Get rid of outliers
wrangled_df = wrangled_df[wrangled_df['2011 revenue'] < ((wrangled_df['2011 revenue'].median()) + 
                                                         wrangled_df['2011 revenue'].std()*3)]
wrangled_df = wrangled_df[wrangled_df['2010 revenue'] < ((wrangled_df['2010 revenue'].median()) + 
                                                         wrangled_df['2010 revenue'].std()*3)]

# %%
# Save the file to a new file
wrangled_df.to_csv('wrangled_transactions.csv')

# %%
wrangled_df.head()
# Out:
#             2010 revenue  days_since_first_purchase  days_since_last_purchase  \
# CustomerID
# 12347.0            52.50                       23.0                      23.0
# 12370.0           271.46                       16.0                      13.0
# 12377.0           129.24                       10.0                      10.0
# 12383.0            22.92                        8.0                       8.0
# 12395.0            89.30                       27.0                      13.0
#
#             number_of_purchases  avg_order_cost  2011 revenue
# CustomerID
# 12347.0                     1.0           52.50        517.81
# 12370.0                     2.0          135.73        203.50
# 12377.0                     1.0          129.24         91.56
# 12383.0                     1.0           22.92        110.60
# 12395.0                     2.0           44.65        265.29

# %% [markdown]
# ### Features Visualization and Correlations

# %%
# Import the saved file
df = pd.read_csv('wrangled_transactions.csv')

# %%
# Relationships between predictors and Outcome
import seaborn as sns
# %matplotlib inline

# %%
sns.pairplot(df)

# %%
# Correlation
df.corr()
# Out:
#                            CustomerID  2010 revenue  \
# CustomerID                   1.000000     -0.184215
# 2010 revenue                -0.184215      1.000000
# days_since_first_purchase    0.082342      0.064314
# days_since_last_purchase     0.084870     -0.187596
# number_of_purchases         -0.044706      0.400478
# avg_order_cost              -0.141921      0.851694
# 2011 revenue                -0.156395      0.555169
#
#                            days_since_first_purchase  \
# CustomerID                                  0.082342
# 2010 revenue                                0.064314
# days_since_first_purchase                   1.000000
# days_since_last_purchase                    0.684896
# number_of_purchases                         0.265994
# avg_order_cost                             -0.056822
# 2011 revenue                                0.088755
#
#                            days_since_last_purchase  number_of_purchases  \
# CustomerID                                 0.084870            -0.044706
# 2010 revenue                              -0.187596             0.400478
# days_since_first_purchase                  0.684896             0.265994
# days_since_last_purchase                   1.000000            -0.378411
# number_of_purchases                       -0.378411             1.000000
# avg_order_cost                            -0.047512            -0.006211
# 2011 revenue                              -0.125192             0.386499
#
#                            avg_order_cost  2011 revenue
# CustomerID                      -0.141921     -0.156395
# 2010 revenue                     0.851694      0.555169
# days_since_first_purchase       -0.056822      0.088755
# days_since_last_purchase        -0.047512     -0.125192
# number_of_purchases             -0.006211      0.386499
# avg_order_cost                   1.000000      0.407200
# 2011 revenue                     0.407200      1.000000

# %% [markdown]
# ### Building the Linear Regression Model

# %%
df = pd.read_csv('wrangled_transactions.csv')

# %%
df.corr()
# Out:
#                            CustomerID  2010 revenue  \
# CustomerID                   1.000000     -0.184215
# 2010 revenue                -0.184215      1.000000
# days_since_first_purchase    0.082342      0.064314
# days_since_last_purchase     0.084870     -0.187596
# number_of_purchases         -0.044706      0.400478
# avg_order_cost              -0.141921      0.851694
# 2011 revenue                -0.156395      0.555169
#
#                            days_since_first_purchase  \
# CustomerID                                  0.082342
# 2010 revenue                                0.064314
# days_since_first_purchase                   1.000000
# days_since_last_purchase                    0.684896
# number_of_purchases                         0.265994
# avg_order_cost                             -0.056822
# 2011 revenue                                0.088755
#
#                            days_since_last_purchase  number_of_purchases  \
# CustomerID                                 0.084870            -0.044706
# 2010 revenue                              -0.187596             0.400478
# days_since_first_purchase                  0.684896             0.265994
# days_since_last_purchase                   1.000000            -0.378411
# number_of_purchases                       -0.378411             1.000000
# avg_order_cost                            -0.047512            -0.006211
# 2011 revenue                              -0.125192             0.386499
#
#                            avg_order_cost  2011 revenue
# CustomerID                      -0.141921     -0.156395
# 2010 revenue                     0.851694      0.555169
# days_since_first_purchase       -0.056822      0.088755
# days_since_last_purchase        -0.047512     -0.125192
# number_of_purchases             -0.006211      0.386499
# avg_order_cost                   1.000000      0.407200
# 2011 revenue                     0.407200      1.000000

# %%
X = df[['2010 revenue',
      'days_since_last_purchase',
      'number_of_purchases',
      'avg_order_cost']]

# %%
y = df['2011 revenue']

# %%
# Split dataset to train and test data
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 100)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Get the model coeeficients
model.coef_
# Out:
# array([  2.47304542,   5.77319371, 207.95901782,   0.84712033])

# %%
# Check the intercepts
model.intercept_
# Out:
# -237.19750662513366

# %%
# Model equations

# %% [markdown]
# ### Lets make a prediction

# %%
single_customer = pd.DataFrame({
    '2010 revenue' : [1000],
    'days_since_last_purchase' : [20],
    'number_of_purchases' : [2],
    'avg_order_cost' : [500]
})

# %%
model.predict(single_customer)
# Out:
# array([3190.78999506])

# %% [markdown]
# ### Plot the model's prediction against true value

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(model.predict(X_test), y_test)
plt.xlim(0,10000)
plt.ylim(0,10000)
plt.plot([0, 10000], [0, 10000], 'k-', color = 'r')
plt.xlabel('Model Prediction')
plt.ylabel("True Value")
plt.show()

# %%
from scipy.stats.stats import pearsonr

pearsonr(model.predict(X_test), y_test)
# Out:
# (0.4961078685946887, 3.4248552576514346e-10)
